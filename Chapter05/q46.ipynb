# %%
import CaboCha


fname_parsed = 'ai.ja/ai.ja.txt.parsed'

# %%
class Morph:
    def __init__(self, dct):
        self.surface = dct['surface']
        self.base = dct['base']
        self.pos = dct['pos']
        self.pos1 = dct['pos1']
        
    def __str__(self):
        return "surface:'{}',  base: '{}', pos: '{}',  pos1: '{}'"\
            .format(self.surface, self.base, self.pos, self.pos1)
    

class Chunk:
    def __init__(self, morphs, dst):
        self.morphs = morphs     # 形態素（Morphオブジェクト）のリスト
        self.dst = dst                   # 係り先文節インデックス番号
        self.srcs = []                    # 係り元文節インデックス番号のリスト
        
    def __str__(self):
        return "morphs:'{}',  dst: '{}', srcs: '{}'"\
            .format(self.morphs, self.dst, self.srcs)

# %%
def dependency_analysis(paragraph) -> list:
    '''ependency_analysis(係り受け解析)の説明
    paragraphはcabocha(CaboCha.FORMAT_LATTICE)で解析したあとのパラグラフとする
    例 出力例(道具を用いて『知能』を研究する)
    形態素のリスト（morphs），係り先文節インデックス番号（dst），係り元文節インデックス番号のリスト（srcs）
    9.　　 ['道具', 'を'] 10 [5, 6, 8]
    10. ['用い', 'て'] 12 [9]
    11. ['『', '知能', '』', 'を'] 12 []
    12. ['研究', 'する'] 13 [10, 11]
    '''
    morphs =[]
    chunks = []
    lines = paragraph.split('\n')
    for line in lines:
        if line == '':
             chunks.append(Chunk(morphs, dst))
        elif line[0]=='*':
            if len(morphs) > 0:
                chunks.append(Chunk(morphs, dst))
                morphs =[]
            dst = int(line.split(' ')[2].rstrip('D'))
        else:
            cols = line.split('\t')
            cols = [cols[0]] + cols[1].split(',')
            dct = {
                'surface': cols[0],
                'base': cols[7],
                'pos': cols[1],
                'pos1': cols[2]
            }
            morphs.append(Morph(dct))
            
    for  i, chunk in enumerate(chunks):
        if chunk.dst != -1:
            chunks[chunk.dst].srcs.append(i)
            
    return chunks


# in_fileはテキストファイルをcabocha(CaboCha.FORMAT_LATTICE)で解析した後のテキストファイル
with open(fname_parsed) as in_file:
    paragraphs = in_file.read().split('EOS\n')
    
paragraphs = list(filter(lambda x: x!='', paragraphs))

# パラグラフごとに係り受け解析をし, リストに格納
paragraphs = [dependency_analysis(paragraph) for paragraph in paragraphs]

# %%
for paragraph in paragraphs:
    for chunk in paragraph:
        for morph in chunk.morphs:
            if morph.pos=='動詞':
                verb  = morph.base
                print(verb, end='\t')
                lst = []
                for src in chunk.srcs:
                    if paragraph[src].morphs[-1].pos == '助詞':
                        particle = paragraph[src].morphs[-1].base
                        lst.append( ''.join([morph.surface if morph.pos != '記号' else '' for morph in paragraph[src].morphs]))
                        print(particle, end=' ')
                print(*lst)
                break
# Out:
# 用いる	を 道具を
# する	て を 用いて 知能を
# 指す	を 一分野を
# 代わる	を に 知的行動を 人間に
# 行う	て に 代わって コンピューターに
# する	も 研究分野とも
# 述べる	は に 佐藤理史は 次のように
# する	を で 知的能力を コンピュータ上で
# する	を 推論判断を
# する	を 画像データを
# する	て を 解析して パターンを
# ある	は が 応用例は 画像認識等が
# する	に で により 1956年に ダートマス会議で ジョンマッカーシーにより
# 用いる	を 記号処理を
# する	を と 記述を 主体と
# 使う	でも 意味あいでも
# 呼ぶ	も 思考ルーチンも
# ある	も ことも
# する	を カウンセラーを
# 出す	が に 人工無脳が 引き合いに
# する	に を 計算機に 役割を
# 呼ぶ	と エキスパートシステムと
# 持つ	が に 人間が 暗黙に
# なる	が と 記述が 問題と
# する	が 利用が
# 知る	も アプローチも
# ある	は に 差は 記号的明示性に
# 集める	が を サポートベクターマシンが 注目を
# 行う	を に を 経験を 元に 学習を
# ある	も 手法も
# する	を に 知性を 機械的に
# する
# 超える	を 流行を
# する	て に 超えて 社会に
# 行く	て 浸透して
# する	を ディープラーニングを
# 破る	も プレイヤーも
# する	が として に MicrosoftSuphx(SuperPhoenix)」が AIとして 十段に
# なる	は と 麻雀では 最先端技術と
# 呼ぶ	は と 人工知能は 機械学習と
# ある	が ものが
# 繰り返す	を 学習を
# する	を と ことを 基本と
# 基づく	に 経験に
# する	と ソフトコンピューティングと
# ある	が ものが
# する	を これらを
# 作る	を 知的システムを
# なす	も 試みも
# する	を に を通して 統計的学習を 元に 生成規則を通して
# 上回る	で を 領域で 人工知能を
# 出す	を 精度を
# 行う	が に 研究が 盛んに
# でる	が 派生が
# する	て で でて 各分野で
# だす	が で を ディープラーニングが 分野で 成果を
# 加える	に ことに
# 見せる	において を 生成技術において 進化を
# 広がる	は が 森正弥は 応用分野が
# 行う	を コンテンツ生成を
# 始まる	も 応用も
# する	と 始まっていると
# 試みる
# なる	が と 解決が 壁と
# する	が と 身体が 機械であると
# する	は を ブレーズ・パスカルは 機械式計算機を
# 行う	は を エイダ・ラブレスは 開発を
# する	を 数学原理を
# もたらす	は に を アルフレッドノースホワイトヘッドは 形式論理に 革命を
# する	に 神経活動に
# 題する	と 論理計算と
# する	は を に ウォルター・ピッツは 論文を 1943年に
# 築く	を 基礎を
# なる	に 1950年代に
# 出る	と に関して が なると AIに関して 成果が
# 作り出す	は で を ジョンマッカーシーは 会議で 用語を
# する	を プログラミング言語を
# ふるまう
# する	を テストを
# する	は を アランチューリングは チューリングテストを
# する	を ジョセフ・ワイゼンバウムはを
# 行う	を 来談者中心療法を
# 行う	に 1956年に
# する	として 用語として
# する	として 分野として
# 示す	は で を ジョエルモーゼスは プログラム中で パワーを
# する	を パーセプトロンを
# 示す	は て を シーモア・パパートは 出版して 限界を
# する	は を アランカルメラウアーは プログラミング言語を
# する	は を テッド・ショートリッフェは ルールベースシステムを
# 示す	を パワーを
# 呼ぶ	と エキスパートシステムと
# ある	も ことも
# する	を に コースを 自律的に
# する	を 乗り物を
# 使う	は によって ニューラルネットワークは バックプロパゲーションアルゴリズムによって
# する	に は を 時代に 知能には 身体性を
# 上げる	は で が を 1990年代は 分野で アプリケーションが 成果を
# する	に 世界チャンピオンに
# する	に は を 1992年に IBMは バックギャモン専用コンピュータTDギャモンを
# 打つ	に を 5月に ガルリ・カスパロフを
# 敗れる	は で に が 8月には オセロで オセロ専用コンピュータ・ロジステロに 村上健が
# する	において を 湾岸戦争において ユニットを
# 使う	のに を スケジューリングするのに AIを
# 省く	によって これによって
# 上回る	が を コストが 投資全額を
# する	を ことを
# する	が に 甘利俊一日本学士院会員らが 精力的に
# する	は も 日本では 成果も
# する	が ブラックボックス性が
# する	は が 1998年には XMLが
# 適す	に アプリケーション別に
# する	から を ここから 意味付けを
# 行う	を 処理を
# する	が 試みが
# 行う	に を Webに 知的処理を
# する	が セマンティック・ウェブが
# する	に を データに 意味を
# 行う	に を コンピュータに 知的処理を
# する	を に 方法を 国際的に
# する	を オントロジーを
# 含む	は も 規格には OWLも
# する
# 分かる	が ことが
# する	に が 前半に 規格化が
# 見合う	に 開発工数に
# 見出せる	が メリットが
# する	は も は Web開発者にとっては 現在も 普及は
# する	は に が 日本においては 後に ニューロファジィが
# 進む	が 研究が
# する	につれて に 進むにつれて フレーム問題に
# する	を 在り方を
# 至る	に AIに
# する	は ブームは
# 入る	に 1980年代に
# 基づく	に 知識工学に
# する	が エキスパートシステムが
# する	を と エキスパートシステムを 専門と
# 立ち上がる	も と AIベンチャーも 次々と
# 生まれる	から 流行から
# 挙げる	として が プロジェクトとして 第五世代コンピュータが
# 費やす	として を 国家プロジェクトとして 570億円を
# 進める	て を 費やして 研究を
# する
# 異なる	で が 専門家間で 解釈が
# する
# 行える	が ルール化が
# ある	は も 場合には 問題も
# 至る	まで は は 1992年まで 日本は 実現には
# する
# する	を で 命令を 機構で
# する	て に 解釈して 高速に
# 見つかる	で が 意味で 応用先が
# 用いる	から として 従来から 手法として
# する	を 問題を
# する	が に 知的制御が 盛んに
# 用いる	を ルールを
# する	を 特徴を
# する	て 学習して
# する	を 2つを
# 迎える	が に を 手法が 中心に ブームを
# 合わせる	に 高級路線に
# 増やす	も を に 白物家電製品でも 種類を 大幅に
# する	に を 元に 運転を
# する	が モデルが
# する	に が を 2018年までに 日本が 特許を
# なる	で と 日本で ブームと
# 分かる	が ことが
# する	より 当時より
# 用いる	は が 白物家電では 制御技術が
# なる	に ものに
# する	は 利用者には
# なる	が に ニューロファジィが ブームに
# する	に 2010年に
# 行う	は は は 1990年代には 概念は 産業応用は
# 巻き込む	も 一般人も
# する	が で ニューラルネットワークが 巻き込んで
# 言える	も 前史とも
# 言える	と 社会現象と
# 持つ	が から が 松下電器が 1985年頃から 人間が
# 活かす	を に 曖昧さを 制御に
# する	を 研究を
# 漕ぎ着ける	に に 1日に 発売に
# する	も で 従来よりも センサーで
# 基づく	に データに
# する	に を 柔軟に 運転を
# する	という が も ファジィ制御という 導入が 高級路線にも
# 関わる	も 制御技術であるにも
# 集める	は を ファジィは 注目を
# 選ぶ	で が 金賞で ファジィが
# する	を チューニングを
# する	を ニューロファジィ制御を
# する	を 限界を
# する	て で 突破して 学会で
# する	も 応用にも
# 巻き起こす	は て を 松下電器は 成功して ブームを
# 受ける	を 成功を
# 用いる	も を 他社も 知的制御を
# する	を 製品を
# 売る	の 白物家電の
# 用いる	として が に 売り文句として 名称が 大々的に
# する	は は は が 製品名では 分類としては 運転モードでは 名称が
# する	を で に 対象を 数式で 客観的に
# 持つ	が を 対象が 機構を
# なる	は は 作業は 場合は
# ある	が 必要が
# する	と 現代制御等と
# する
# なる	が と 特徴が 利用可能と
# 抑える	を 開発工数を
# できる	を 柔軟性を
# ある	は が ニューロファジィは 利点が
# 関わる	も 努力にも
# する	を 制御を
# 迎える	で を 程度で 限界を
# 与える	が に データが 潤沢に
# ある	は が 向上には 限界が
# 進む	から は として 能力限界から 改善は 遅々として
# 目立つ
# 無くなる	は 進展は
# する	を 知的制御を
# なる	は が に 末には 白物家電が 大多数に
# 売る
# 去る	は ブームは
# する	は は ブーム後は 一般には
# なる
# 使う	も 社会インフラにも
# する	は に が 現在では 十分に 安定性が
# する	が 人間が
# する	として ファジィルールとして
# する	を 表現するを
# する	に 分野に
# する	が で を 人工知能が 点で 人間を
# 担う	を 進歩を
# する	を 世界を
# 訪れる	が も シンギュラリティが 2045年にも
# する	と 訪れると
# する	は を レイカーツワイルは 説を
# する	により が 研究チームにより 深層化手法が
# 入る	に 2010年代に
# 扱う	を データを
# する	が 環境が
# する	が 研究が
# する	に で が 2010年に 英国エコノミスト誌で 用語が
# する	で に 練習戦で 人間に
# なる	と ニュースと
# 果たす	に で が を 2012年に 画像処理コンテストで チームが 精度改善を
# する	で 上で
# 始まる	に が 同年に 第三次AIブームが
# する	が 研究チームが
# 挑む	で に 東ロボくんで 模擬試験に
# する	は と 2013年には 挑んだと
# 使う	を 専用プログラムを
# 臨む	に が 実際に 受験生が
# する	を 問題を
# できる
# 先立つ	に 特異点に
# 近づく	により が 進歩により 生産コストが
# する	も 概念も
# 向ける	に 実現に
# 続ける	て を 向けて 研究を
# 考える
# 考える
# する	で を 中で 理論を
# 向ける	に 実用化に
# 進む	に が 軍事民間共に 研究開発が
# する	が 開発が
# 留まる	に ものに
# する	は は は 2010年代には 自動化は UCAVは
# 行う	から 地上から
# する	が ロドニー・ブルックスが
# する	が 理論が
# 思う
# あり
# する	が 知が
# 用いる	を 神経ネットワークのみを
# する	て から 用いて 環境から
# 用いる	は を これは 行動型システムを
# 基づく	に これに
# 呼ぶ	と ゲンギスと
# 持つ	を 脳を
# 関わる	も 持たないにも
# 生きる
# する	に ように
# する	に が 10月に 米DeepMind社が
# する	に プロ囲碁棋士に
# 呼ぶ	と ディープラーニングと
# する	が は が AlphaGoが 勝利して以降は 手法が
# 与える	が に 人工知能が 雇用などに
# 進める	も が 影響についても 研究が
# する
# 導き出す	を 関連性を
# 導き出す	を ものを
# する	を ディファレンシャブル・ニューラル・コンピューターを
# する	が を データが ワンショット学習を
# 持つ	を 認識能力を
# する	を 記号接地問題(シンボルグラウンディング問題)を
# なる	と 計算資源と
# 付ける	で に を 画像処理コンテストで 手法に 圧倒的大差を
# する	に が て 2012年に ディープラーニングが 付けて
# 集める	に を 急速に 注目を
# 持つ	を 現実味を
# 受け止める	は て 概念は 持って
# 受ける	を 普及を
# 率いる
# する	を AGIを
# 立つ	が プロジェクトが
# する	を 脳を
# する	て リバースエンジニアリングして
# 組み合わせる	を 機械学習を
# する	と 有望と
# 扱う	を タスクのみを
# 進む	から ディープラーニングから
# 扱う	を タスクを
# する	が 理論が
# 動かす	で を 仮想空間で モデルを
# 学ぶ	を に ことを 高速に
# 上げる	も を ことも 成果を
# 考える	と 不可能と
# する	を 身体知を
# する	と 必要だと
# 見せる	を 振る舞いを
# 挑む	に 作成に
# ある	に 関係に
# 思う	と あると
# する	に 人工意識に
# いる	も 研究者も
# 入る	で が に コストで 計算リソースが 手に
# する	が ビッグデータが
# 寄せる	が に を 企業が 活用に 関心を
# 行う	に で を 全世界的に 民間企業主導で 投資を
# する	て が 行って 研究開発競争が
# する	が に ITインフラが 急速に
# 関わる	も 高速化にも
# できる	を に 組み合わせ最適化問題を リアルタイムに
# する	が 環境が
# 受ける	を 動向を
# 目立つ	も が ニュース番組でも 報道が
# する	に 急速に
# 取る	に対して が を 人工知能に対して 人間が 遅れを
# する	を に 脳を 機械に
# する	を ブレイン・マシン・インターフェースを
# 立つ	を ニューラ・リンク社を
# する	を ことを
# なる	は で に 2017年には 世界中で 話題に
# する	が インターネットが
# する	が 事が
# 含める	まで 位置関係まで
# できる	は により て 10月には ジェフリーヒントンにより 含めて
# する	が カプセルネットワークが
# よる	に 提言に
# する	を AIを
# できる	で に 事で 社会変革に
# する	と 寄与できると
# する	が を OpenAIが 好奇心を
# 行う	で を 無報酬で 探索を
# いう	と 人間らしいと
# 経る	を 段階を
# する	を て 推論を 経て
# 分かる	が に 識別したのかが 明確に
# する	は を MITリンカーン研究所は アーキテクチャを
# 入る	に 2019年に
# する	と まで と 入ると これまで 困難と
# ある	において が 言語処理において 進展が
# する	を Wikipediaなどを
# 上回る	で を 読解テストで 人間を
# 至る	に 上回るに
# する	と アレン脳科学研究所と
# 生まれる	によって 脳スキャンによって
# する	を データを
# する	は を Googleは ソフトウェアを
# する	が Googleが
# 達す	は に データ量は 1Zettaバイトに
# いう	と 達していると
# 始める	とも を マックスプランク研究所とも 共同研究を
# する	から を 電子顕微鏡写真から 神経回路を
# 行う	を 研究を
# 位置づける	から を に 第13次5カ年計画から AIを 国家プロジェクトに
# 上げる	も 脳研究プロジェクトとしても
# する	は で を 中国では 官民一体で 研究開発を
# 集める	を 天才児を
# 投じる	は て と に 教育機関では 集めて 公然と 開発に
# よる	に 教授やなどに
# する	と 欧米と
# する	を 実験を
# ある	は て に 中国では 比較して 環境に
# する	と あると
# する	で を 日本で 研究開発を
# する	も において が 齊藤元章も 開発において 中国が
# する	を 可能性を
# 占める	が 中国が
# する	は も 4分の3は 占めてるとも
# よる	に 米国政府に
# 超える	を 米国を
# なる	から は が て と 2013年から 論文数では 中国が 超えて 世界一と
# する	も が を 大会でも 中国勢が 上位を
# ある	でも 幹部でも
# 握る	が で を 中国が AIで 覇権を
# する	と 握りつつあると
# 著す	を を
# 取り上げる	は て が 台湾系アメリカ人科学者のは 著して メディアなどが
# 向ける	に 開発支援に
# する	で を 5年で 約1600億円を
# する	と 支出すると
# 開く	を に AI研究所を パリに
# する	は を フランス大統領エマニュエル・マクロンは 富士通などを
# する	も 連携も
# 投じる	が 215億ユーロが
# する	に を 2022年までに 投資を
# する	を AI機関を
# 作る	も 褒賞制度も
# 入る	は に に 目標は 2022年までに 世界トップ4に
# いう	と 入ることだと
# よる	に 日経新聞調べに
# 使う	は が プログラミング言語は Pythonが
# する	を 深層学習を
# なる	が と 数学知識が 必要と
# 行う	を 脳シミュレーションを
# なる	は も 行うには 知識も
# 超える	を 人間を
# 於く	に 超えるか内に
# 起こす	に対して を 人間に対して 反乱を
# する	は を 人工知能は 可能性を
# 鳴らす	を 警鐘を
# いる	も 著名人も
# 併せ持つ	を 弾圧を
# する	が で 中華人民共和国が 開発競争で
# 変わる	は が 教授は 既成概念が
# 述べる	と 変わると
# 呼ぶ	と 一人と
# する	が で を 中国が 政治目的で 人工知能を
# 鳴らす	は に を 呼ばれているは ことに 警鐘を
# する	に 中国に
# する	で を 人工知能で 人権を
# 呼ぶ	は を と メディアなどは 政治体制を AI独裁と
# 埋め込む	に 帽子に
# する	から を で センサーから 感情を 人工知能で
# 推し進める	が プロジェクトが
# 行う	まで を に 歩行者まで 監視を 人工知能に
# する	に を ロボットに 天網を
# 行う	は が 中国では 監視社会管理社会化が
# する	から 携帯電話などから
# する	で 人工知能で
# する	を で 個人情報を 人種プロファイリングで
# 経る	を を ウイグル族を 法的手続きを
# 犯す	に で も を 経ずに 6月時点で 約1万5千人も 犯罪を
# ある	が 可能性が
# する	は として に 新疆ウイグル自治区では あるとして 新疆ウイグル再教育キャンプに
# する	と 予防拘禁していると
# 報じる	が 内部文書であるが
# 使う	を AIを
# 送る	が を に コンピュータが 人間を 強制収容所に
# なる	は として に 人権侵害は ないとして 国際問題に
# 恐れる	を 監視社会化を
# 起きる	が 香港民主化デモが
# する	を 監視カメラを
# する	は が に と 際は スマート街灯が 市民に 次々と
# する	は を に 中国は AI監視技術を 世界各国に
# する	を通じて が も ITUを通じて 中国が 国際標準化も
# する	が に 人権侵害が 世界に
# する	から が から ことから ことが 人権団体などから
# する	に 社会信用システムに
# する	で を 人工知能で ビッグデータを
# 決める	て を 活用して 適性を
# する	を 格差を
# 繋がる	に ことに
# する	と 繋がると
# ある	が 懸念が
# 認める	を 差別を
# する	は が 欧州連合では EU一般データ保護規則が
# 達す	で は に 9割超で IBMは 8割に
# ある	に対して は で が 達したのに対して Amazonは 6割で バイアスが
# する	と あると
# する	を 研究を
# なる	が で は は と に マサチューセッツ工科大学が 精度で Megviiは 際は Amazonと 論争に
# 試みる	を 自動化を
# する	を ファランクスCIWSを
# できる	は により を アメリカ海軍は ガトリング砲により 対艦ミサイルを
# する	は を イスラエル軍は アイアンドームを
# する	を 標的を
# する	を サムソンRCWSを
# する	は て を 境界線には 稼働させて 人間を
# 生む	は を AIは 軍事能力を
# 変える	を 展開を
# する	を 戦争を
# 決める	を 軍事バランスを
# なる	は に 変化は ことに
# ある	も 主張も
# する	に に に 1(哨戒機)のように 戦闘指揮システムに 支援用に
# ある	も ことも
# する	が 研究チームが
# する	に 一方的に
# する	と 勝利したと
# する	は を AIプログラムは ファジィ制御を
# する	は と 処理能力は 必要と
# 介す	から を 観点から 判断を
# 出す	を に 開発禁止令を 2012年に
# する	は を に 2017年には これを ものに
# 勝ち残る	に が 人工知能に 人間が
# する	が OODAループが
# する	により は 軍事利用により 不安定化は
# する	と 加速すると
# する	に で 2015年に ブエノスアイレスで
# 出す	により が 企業家らにより 公開書簡が
# 操る	を 銃火器を
# 続く	に 核兵器に
# とらえる	と 革命と
# なる	は に 一部は 数年以内に
# する	に 選別攻撃などに
# なる	が にとって は 開発競争が 人類にとって ものとは
# 記す	と ならないと
# 求める	は を 4月には 禁止を
# 行う	は で が 11月には 国際連合で 公式専門家会議が
# めぐる	を 運用を
# する	を 国際ルールを
# 盛り込む	に は も は 8月に 同会議は 採択するも 法的拘束力は
# ある	に 状態に
# 評す	も あるとも
# する	に 核開発に
# 行う	は を をめぐって 米国中国ロシアは 開発競争を 軍事利用をめぐって
# する	に で に 6月に 自律飛行実験で 飛行実験に
# する	を 記録を
# する	を 都市を
# する	て は も 更新して 5月には 映像も
# 使う	を 自律無人艇を
# 行う	を 試験を
# 呼ぶ	と スウォームと
# する	は など で が に 6月には 行うなど 統合運用で 中国が 急速に
# 追い付く	に アメリカに
# ある	が 可能性が
# する	について ことについて
# 備える	に 将来に
# ある	は が アメリカ側では 必要が
# する	は も 中国は 主張も
# 与える	は に を 軍用AI開発は 政界に 危機感を
# する	で に 設立などで 中国人民解放軍に
# する	と を 協力していると Googleを
# する	と トランプ大統領と
# 限る	に 中国に
# する	は て は に CEOサンダー・ピチャイは 面談して 成果は 人々に
# する	と 開放されていると
# なる	は に ドナルドトランプ大統領は 事態に
# する	が に Googleが 軍事利用に
# 行う	を メイヴン計画を
# する	は が に アメリカでは ことが 社員に
# する	に 同様に
# する	に 中国政府に
# 用いる	を 人工知能を
# する	は 人権侵害は
# 誓う	が Googleが
# 受ける	と で を 拒否すると 整合性で 追及を
# 関わる	に が 標的選択支援アルゴリズムに AI研究者が
# する	と 関わったと
# する	は と 際は モデリングと
# する	が を Microsoftが 共同研究を
# 呼ぶ	も に を 際も 同様に 波紋を
# する	が によって を 中国が AIによって 監視国家を
# する	で を に 中東で 無人攻撃機を 大量に
# する	て で に 拡散させて AIで 自律的に
# する	も ドローン兵器も
# 鳴らす	に は に を 11月に マーク・エスパー国防長官は ことに 警鐘を
# する	は 中国は
# する	と 実用化してると
# する	を 個人を
# なりすます	たり で 攻撃したり ディープフェイクで
# 操る	により を ボット投稿により 世論を
# 挙げる	が 懸念が
# する	を で 人工知能プロジェクトを 倫理面で
# する	に で ために 哲学者政策立案者経済学者テクノロジスト等で
# する	を AI倫理委員会を
# する	は と Googleは 設置すると
# する	を 反科学反マイノリティ・地球温暖化懐疑論等を
# 含む	は も 倫理委員会には 人物も
# する	は を Google社員らは 解任を
# できる	に 期待どおりに
# する	が ことが
# する	は が を Googleは 倫理委員会が 解散を
# する	を に 東洋哲学を AIに
# 応じる	に テーマに
# 挙げる	は を 井口尊仁は プロジェクトを
# 見いだす	に を ものに 霊的存在を
# ある	が 文化が
# 語る	と に ありますと 立石従寛に
# やる	を 悟りを
# やる	て に やって AIに
# 論じる	を やらせるかを
# 通じる	は も アニミズム的人工知能論は 哲学塾東洋哲学篇にも
# する	を と AIを 神と
# する	を 道)」を
# 基づく	に AIに
# する	を 実現を
# する
# する	を通して を 崇拝を通して 社会を
# する	に ことに
# する	は と に 使命は ことと 抽象的に
# 関連付ける	と 歴史などと
# する	は て 海外メディアは 関連付けて
# する	が を レバンドウスキーが 機密情報を
# 訴える	を ことを
# 行う	を 裁判を
# する	は を 我々は 世界を
# する	に対し と トラビスカラニックに対し 征服するんだと
# 示す	は は を アンソニーレバンドウスキーは レバンドウスキーは 振る舞いを
# なる	も 線引きも
# 述べる	は と 釈徹宗は 不明瞭になってきていますと
# よる	に 内田樹に
# する	は を 哲学者は 話を
# いう	と していると
# 言う	が 発明家レイカーツワイルが
# する	が 哲学者ジョンサールが
# よる	に ダニエル・デネットに
# できる	が によって 意識が 形式論理システムによって
# する	と 実現できないと
# 語る	を 科学を
# する	と 科学と
# する	は を 実際には ことを
# する	を 問題を
# する	に コンピュータ科学人工知能研究開発等に
# 残す	も を 何も 成果を
# する	は と フランシスクリックは 残してこなかったと
# 過ぎる	は に 哲学は 学問科学に
# する	と 過ぎないと
# する	に クリックに
# まじる	の 私の
# なる	は に これは 愚痴に
# 思う	は と 思想家というのは 暇だと
# 述べる	と 思うと
# 始まる	は から 哲学は スコレーから
# 伝える	と が 始まったと アリストテレスが
# 言う	において は ことかにおいて 野家啓一は
# 違う	は 科学とは
# 語る	で を 日常的言語で 宇宙を
# する	を 哲学者を
# 見る	が ディラックが
# 含める	を ウィトゲンシュタインを
# する	さえ 概念さえ
# 使う	を 日常的言語を
# 行う	を 意思疎通を
# できる	は ことは
# する	と 考えだと
# 創る	は 人工知能は
# よる	に 創られるに
# 伴う	に 発展に
# 論じる	て が で 伴って 哲学が 一部で
# 言う	と 特異点と
# する	と シンギュラリティと
# 超える	における を 議論における 脳を
# できる	が 言明自体が
# 記す	は と 前掲書は 定義できていないと
# 捉える	を として 脳を デジタル情報処理システムとして
# 見る	から 観点から
# 起こる	は シンギュラリティは
# する	が アナログが
# 示す	で 観察結果で
# よる	に 前掲書に
# する	は が 神経膜では ノイズが
# 生み出す	によって が アナログ量によって カオスが
# する	を で 状況を デジタルで
# 考える	は と 脳は 困難と
# 述べる	は と 田中一之は 専門家ではないと
# 基づく	に 自由連想に
# する	が と 多くが 基づいていると
# よる	に 田中に
# 書く	について が 不完全性定理について 哲学者が
# する	に 頃に
# する	は によって 本は 専門誌によって
# 読む
# する	を 勘違いを
# する
# 見る	は も 間違いは 入門書などにも
# よる	に フランセーンに
# 起こる	は に 誤解誤用は 一般に
# する	も 神学でも
# 示す	に が 1931年に ゲーデルが
# 語る	を 科学を
# よる	に ことかに
# 扱う	の 学問の
# する	が 問題が
# する
# 異なる	も 哲学も
# する	を 問題を
# 言う	と は 進歩だと 須藤は
# 含む	を 要素を
# 扱う	を に 大きな問題を 哲学的統一的に
# する	について 天文学について
# 扱う	は を 天文学では 哲学的問題を
# 扱う	も を 物理学でも 問題を
# 述べる	と 扱わないと
# ある	に か が それ自体に 何か 問題が
# 返す	は と 須藤は あるのでしょうかと
# 述べる	は は も これは 須藤は 次のようにも
# 論じる	に 哲学的に
# 取り上げる	を 言葉を
# する	を に 言葉を 具体的に
# 述べる	と 不可能ですと
# 持つ	が を 哲学者が 興味を
# 違う	が は 定義が 物理学者とは
# する	と 確かでしょうと
# 思う
# しれる	は 違いというのは
# 述べる	と 大きいのかもしれませんと
# 行う	まで を これまで 議論を
# なる	は 違いは
# 思う	は 明らかになったとは
# つく	か が 何か 決着が
# する	は と 須藤は つくのでしょうかと
# つく	は 決着は
# 答える	で は と 対談で 伊勢田は つかないでしょうねと
